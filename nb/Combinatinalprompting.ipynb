# %% [markdown]
# <a href="https://colab.research.google.com/github/SomTheSheep/Unsloth/blob/master/nb/Combinatinalprompting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# Unsloth now supports Text-to-Speech (TTS) models. Read our [guide here](https://docs.unsloth.ai/basics/text-to-speech-tts-fine-tuning).
#
# Read our **[Gemma 3N Guide](https://docs.unsloth.ai/basics/gemma-3n-how-to-run-and-fine-tune)** and check out our new **[Dynamic 2.0](https://docs.unsloth.ai/basics/unsloth-dynamic-2.0-ggufs)** quants which outperforms other quantization methods!
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" huggingface_hub hf_transfer
    # !pip install --no-deps unsloth

# %% [markdown]
# ### Unsloth

# %%
from unsloth import FastVisionModel # FastLanguageModel for LLMs
import torch

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Llama-3.2-11B-Vision-Instruct-bnb-4bit", # Llama 3.2 vision support
    "unsloth/Llama-3.2-11B-Vision-bnb-4bit",
    "unsloth/Llama-3.2-90B-Vision-Instruct-bnb-4bit", # Can fit in a 80GB card!
    "unsloth/Llama-3.2-90B-Vision-bnb-4bit",

    "unsloth/Pixtral-12B-2409-bnb-4bit",              # Pixtral fits in 16GB!
    "unsloth/Pixtral-12B-Base-2409-bnb-4bit",         # Pixtral base model

    "unsloth/Qwen2-VL-2B-Instruct-bnb-4bit",          # Qwen2 VL support
    "unsloth/Qwen2-VL-7B-Instruct-bnb-4bit",
    "unsloth/Qwen2-VL-72B-Instruct-bnb-4bit",

    "unsloth/llava-v1.6-mistral-7b-hf-bnb-4bit",      # Any Llava variant works!
    "unsloth/llava-1.5-7b-hf-bnb-4bit",
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastVisionModel.from_pretrained(
    "unsloth/llava-1.5-7b-hf-bnb-4bit",
    load_in_4bit = True, # Use 4bit to reduce memory use. False for 16bit LoRA.
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for long context
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.8.1: Fast Clip patching. Transformers: 4.54.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/4.04G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/136 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/701 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/505 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/41.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters for parameter efficient finetuning - this allows us to only efficiently train 1% of all parameters.
#
# **[NEW]** We also support finetuning ONLY the vision part of the model, or ONLY the language part. Or you can select both! You can also select to finetune the attention or the MLP layers!

# %%
model = FastVisionModel.get_peft_model(
    model,
    finetune_vision_layers     = True, # False if not finetuning vision layers
    finetune_language_layers   = True, # False if not finetuning language layers
    finetune_attention_modules = True, # False if not finetuning attention layers
    finetune_mlp_modules       = True, # False if not finetuning MLP layers

    r = 16,           # The larger, the higher the accuracy, but might overfit
    lora_alpha = 16,  # Recommended alpha == r at least
    lora_dropout = 0,
    bias = "none",
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
    # target_modules = "all-linear", # Optional now! Can specify a list if needed
)

# %%
import os
import json
from PIL import Image
import matplotlib.pyplot as plt
from transformers import TextStreamer
import numpy as np
import torch.nn.functional as F

# %% [markdown]
# Expected folder structure
# ![image.png](data:image/png;base64,...)

# %%
# 3. Set up Directories and Paths
root_dir = "/DocVQA"
image_dir = os.path.join(root_dir, "Images", "Val")
ocr_dir = os.path.join(root_dir, "OCR", "Val")
qa_dir = os.path.join(root_dir, "QA", "Val")

# Output JSON file for results
output_path = "/content/prompt_outputs_multimodal_val.json"

# %%
#4 Replace with your model and tokenizer initialization
# Assumes `model` and `tokenizer` are already loaded elsewhere (or load them here)
FastVisionModel.for_inference(model)
text_streamer = TextStreamer(tokenizer, skip_prompt=True)

# %%
# 5. Helper Function to Extract Text
def extract_text_from_ocr(ocr_data):
    """Extract all text from OCR JSON data."""
    text_content = []
    if "recognitionResults" in ocr_data:
        for result in ocr_data["recognitionResults"]:
            if "lines" in result:
                for line in result["lines"]:
                    text_content.append(line["text"])
    return "\n".join(text_content)

# %%
# NEW CELL
import re
import string

def levenshtein_distance(s1, s2):
    """Calculates the Levenshtein distance between two strings."""
    if len(s1) < len(s2):
        return levenshtein_distance(s2, s1)
    if len(s2) == 0:
        return len(s1)
    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    return previous_row[-1]

def normalize_text(s):
    """Lower text and remove punctuation, articles and extra whitespace."""
    s = s.lower()
    s = "".join(ch for ch in s if ch not in set(string.punctuation))
    s = re.sub(r"\b(a|an|the)\b", " ", s)
    s = " ".join(s.split())
    return s

def calculate_anls(prediction, ground_truths):
    """
    Calculates the Average Normalized Levenshtein Similarity (ANLS).
    The final score is the maximum ANLS score against all ground truth answers.
    """
    if not ground_truths:
        return 0.0

    prediction_norm = normalize_text(prediction)
    max_anls = 0.0

    for gt in ground_truths:
        gt_norm = normalize_text(gt)
        distance = levenshtein_distance(prediction_norm, gt_norm)
        max_len = max(len(prediction_norm), len(gt_norm))
        if max_len == 0:
            anls = 1.0 if distance == 0 else 0.0
        else:
            anls = 1.0 - (distance / max_len)
        if anls > max_anls:
            max_anls = anls

    return max_anls

def calculate_extractive_match(prediction, ground_truths):
    """
    Calculates if any ground truth is a substring of the prediction.
    Returns 1.0 for a match, 0.0 otherwise.
    """
    if not ground_truths:
        return 0.0

    prediction_norm = normalize_text(prediction)

    for gt in ground_truths:
        gt_norm = normalize_text(gt)
        if gt_norm in prediction_norm:
            return 1.0 # Found a match

    return 0.0 # No match found

def calculate_strict_match(prediction, ground_truths):
    """
    Calculates the strict match category based on normalized text.
    """
    prediction_norm = normalize_text(prediction)
    has_prediction = bool(prediction_norm)
    has_ground_truth = bool(ground_truths)

    if has_ground_truth:
        if not has_prediction:
            return "Missing"  # Expected an answer, but got none.

        ground_truths_norm = [normalize_text(gt) for gt in ground_truths]
        if prediction_norm in ground_truths_norm:
            return "Correct"  # Prediction matches a ground truth.
        else:
            return "Incorrect"  # Prediction does not match any ground truth.
    else: # No ground truth
        if has_prediction:
            return "Spurious"  # Predicted an answer, but none was expected.
        else:
            return "Correct" # Correctly predicted nothing when nothing was expected.
def calculate_confusion_matrix(prediction, ground_truths):
    """
    Calculates TP, FP, TN, FN based on extractive match logic.
    - Positive Case (has ground truth):
        - TP: Prediction contains a ground truth.
        - FN: Prediction does not contain a ground truth.
    - Negative Case (no ground truth):
        - TN: Prediction is empty.
        - FP: Prediction is not empty.
    """
    prediction_norm = normalize_text(prediction)
    has_prediction = bool(prediction_norm)
    has_ground_truth = bool(ground_truths)

    # Positive Case: A ground truth exists.
    if has_ground_truth:
        # Check if any ground truth is in the prediction (extractive match)
        match_found = False
        for gt in ground_truths:
            if normalize_text(gt) in prediction_norm:
                match_found = True
                break
        if match_found:
            return {"tp": 1, "fp": 0, "tn": 0, "fn": 0}  # True Positive
        else:
            return {"tp": 0, "fp": 0, "tn": 0, "fn": 1}  # False Negative

    # Negative Case: No ground truth exists.
    else:
        if not has_prediction:
            return {"tp": 0, "fp": 0, "tn": 1, "fn": 0}  # True Negative
        else:
            return {"tp": 0, "fp": 1, "tn": 0, "fn": 0}  #

# %%
# 6. Main Processing Loop
# Collect all QA files
qa_files = sorted(os.listdir(qa_dir))

# Initialize the output data list, this will overwrite the file on each run.
all_data = []

# Initialize strict match counters
strict_match_counts = {"Correct": 0, "Incorrect": 0, "Missing": 0, "Spurious": 0}

# Initialize confusion matrix counters
confusion_matrix_counts = {"tp": 0, "fp": 0, "tn": 0, "fn": 0}

# Iterate through each QA file to process the corresponding documents
for qa_filename in qa_files:
    file_id = qa_filename.replace(".json", "")
    qa_file_path = os.path.join(qa_dir, qa_filename)
    ocr_file_path = os.path.join(ocr_dir, f"{file_id}.json")
    image_path = os.path.join(image_dir, f"{file_id}.png") # Assuming images are .png

    # Skip if any of the required files are missing
    if not os.path.exists(image_path):
        print(f"Image file not found for {file_id} at {image_path}, skipping.")
        continue
    if not os.path.exists(ocr_file_path):
        print(f"OCR file not found for {file_id} at {ocr_file_path}, skipping.")
        continue

    # Load the document image
    try:
        image = Image.open(image_path)
    except Exception as e:
        print(f"Error opening image {image_path}: {e}")
        continue

    # Load and extract text from the OCR data
    with open(ocr_file_path, "r") as f:
        ocr_data = json.load(f)
    document_text = extract_text_from_ocr(ocr_data)

    # Load the questions for the current document
    with open(qa_file_path, "r") as f:
        qa_items = json.load(f)

    # --- NEW LOGIC: Combine all questions into one prompt ---
    if qa_items:
        # 1. Aggregate all questions into a single string
        all_questions_text = ""
        for i, qa in enumerate(qa_items):
            all_questions_text += f"{i+1}. {qa['question']}\n"

        # 2. Create a new prompt instructing the model to answer all questions
        enhanced_question = f"""Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").

Document text:
{document_text}

Questions:
{all_questions_text}
Answers:"""

        # 3. Prepare and tokenize the single combined prompt
        messages = [
            {"role": "user", "content": [
                {"type": "image"},
                {"type": "text", "text": enhanced_question}
            ]}
        ]
        input_text = tokenizer.apply_chat_template(messages, add_generation_prompt=True)
        inputs = tokenizer(
            image,
            input_text,
            add_special_tokens=False,
            return_tensors="pt"
        ).to("cuda")

        # 4. Generate one combined response from the model
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=512, # Increased max tokens for multiple answers
                use_cache=False,
                temperature=1.5,
                min_p=0.1,
            )

        decoded_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
        output_text = decoded_output.strip()

        print(f"\n[Document: {file_id}]")
        print(f"--- Combined Prompt Sent ---")
        print(enhanced_question)
        print(f"\n--- Combined Output Received ---")
        print(output_text)

        # --- NEW LOGIC: Parse the combined output and evaluate each answer ---

        # 1. Isolate the part of the string generated by the assistant
        if "ASSISTANT:" in output_text:
            answers_block = output_text.split("ASSISTANT:")[-1].strip()
        else:
            # Fallback if the model doesn't follow the template exactly
            answers_block = output_text

        # 2. Parse the block of answers into a list
        predicted_answers = [line.strip() for line in answers_block.split('\n') if line.strip()]

        # 3. Loop through the original questions and match them with predicted answers
        for i, qa in enumerate(qa_items):
            question = qa["question"]
            ground_truth_answers = qa.get("answers", [])

            # Get the corresponding predicted answer, with a safeguard
            if i < len(predicted_answers):
                # Clean the answer by removing the leading "n. " part
                raw_prediction = re.sub(r'^\d+\.\s*', '', predicted_answers[i])
            else:
                raw_prediction = "" # No prediction was found for this question

            # Calculate metrics for this specific question
            anls_score = calculate_anls(raw_prediction, ground_truth_answers)
            extractive_match = calculate_extractive_match(raw_prediction, ground_truth_answers)
            strict_match = calculate_strict_match(raw_prediction, ground_truth_answers)
            cm_result = calculate_confusion_matrix(raw_prediction, ground_truth_answers)

            # Update overall counters
            strict_match_counts[strict_match] += 1
            for key in confusion_matrix_counts:
                confusion_matrix_counts[key] += cm_result[key]

            # Store the detailed result for this question
            all_data.append({
                "Document": file_id,
                "question": question,
                "output": raw_prediction,
                "ground_truth": ground_truth_answers,
                "anls_score": anls_score,
                "extractive_match": extractive_match,
                "strict_match": strict_match,
                "confusion_matrix": cm_result,
            })

# 7. Save All Results to a JSON File
with open(output_path, "w") as f:
    json.dump(all_data, f, indent=2)

print(f"\nProcessing complete. All results saved to {output_path}")
# Out:
# [Document: ffbg0227_2]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# Robert E. Shank, M.D.
# Page 2
# April 17, 1972
# As you know, each candidate selects the area of special emphasis
# to be covered in depth in his examinations. We are attempting to compile
# for each area topics or rubrics within which questions may be developed.
# We should like to express our appreciation for your response to Dr. Harold
# Ellingson's request for help in this regard. The suggestions from last
# fall's examiners have given us an excellent start in this undertaking.
# We hope, too, to have a list of recommended essential readings for each
# area, and will appreciate receiving your suggestions for such a list.
# Please accept my personal thanks and those of the Board for your
# cooperation.
# Sincerely,
# Bill
# William P. Richardson, M. D.
# Vice Chairman, General Preventive
# Medicine
# WPR :m jm
# Enclosure
# Source: https://www.industrydocuments.ucsf.edu/docs/ffbg0227
#
# Questions:
# 1. what is the page no or page mentioned ?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# Robert E. Shank, M.D.
# Page 2
# April 17, 1972
# As you know, each candidate selects the area of special emphasis
# to be covered in depth in his examinations. We are attempting to compile
# for each area topics or rubrics within which questions may be developed.
# We should like to express our appreciation for your response to Dr. Harold
# Ellingson's request for help in this regard. The suggestions from last
# fall's examiners have given us an excellent start in this undertaking.
# We hope, too, to have a list of recommended essential readings for each
# area, and will appreciate receiving your suggestions for such a list.
# Please accept my personal thanks and those of the Board for your
# cooperation.
# Sincerely,
# Bill
# William P. Richardson, M. D.
# Vice Chairman, General Preventive
# Medicine
# WPR :m jm
# Enclosure
# Source: https://www.industrydocuments.ucsf.edu/docs/ffbg0227
#
# Questions:
# 1. what is the page no or page mentioned ?
#
# Answers: ASSISTANT: 1. The page number is 2.
#
# [Document: ffhx0227_1]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# VANDERBILT UNIVERSITY - THE LIVING ENDOWMENT
# On behalf of Vanderbilt University we gratefully acknowledge your gift in
# the amount of $5,000 ( Grant No. 452 for Dr. 6. E.
# Nichoalds)
# Cr: 5304-4837-082-13
# The Nutrition Foundation, Inc.
# 99 Park Avenue
# New York, N.Y. 10016
# AUG 2, 1971
# Attn: Dr. Horace L. Sipple
# LULIVL
# L
# 7/15/71 LB
# GIFTS MADE TO VANDERBILT UNIVERSITY CONSTITUTE A DEDUCTION UNDER INCOME TAX LAWS.
# Source: ht
# ww.industr
# cuments.LIC
# No..A 2,2941
#
# Questions:
# 1. What is the name of the University?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# VANDERBILT UNIVERSITY - THE LIVING ENDOWMENT
# On behalf of Vanderbilt University we gratefully acknowledge your gift in
# the amount of $5,000 ( Grant No. 452 for Dr. 6. E.
# Nichoalds)
# Cr: 5304-4837-082-13
# The Nutrition Foundation, Inc.
# 99 Park Avenue
# New York, N.Y. 10016
# AUG 2, 1971
# Attn: Dr. Horace L. Sipple
# LULIVL
# L
# 7/15/71 LB
# GIFTS MADE TO VANDERBILT UNIVERSITY CONSTITUTE A DEDUCTION UNDER INCOME TAX LAWS.
# Source: ht
# ww.industr
# cuments.LIC
# No..A 2,2941
#
# Questions:
# 1. What is the name of the University?
#
# Answers: ASSISTANT: Vanderbilt University
#
# [Document: ffjw0228_11]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# SCHEDULE 1
# ALCOHOLIC BEVERAGE MEDICAL RESEARCH FOUNDATION
# SCHEDULE OF ADMINISTRATION EXPENSES - HEADQUARTERS
# Year Ending December 31,
# 1987
# 1986*
# Salaries
# Travel, Including Public Trustees
# $117 , 047
# $123, 110
# Employee Benefits
# 29,928
# 18,559
# 21,844
# Publications
# 10 ,596
# 23,453
# 3,700
# Office Expenses
# 9,345
# Rent
# 9, 154
# 8,721
# 9, 020
# Legal
# 8,399
# 1 , 354
# Insurance
# 7,442
# Honoraria
# 7,000
# 6,792
# Accounting
# 7,000
# 6,459
# Meetings
# 6,348
# 4,536
# Service Fee
# 4,416
# 2,635
# Telephone
# 4,671
# 2,958
# Public Relations
# 2, 129
# -0-
# 14,383
# $235,839
# $235, 160
# SCHEDULE 2
# SCHEDULE OF EXPENSES - TECHNICAL SUPPORT
# Medical Intelligence
# $ 53,568
# Biostatistics
# $ 30, 052
# 44 ,851
# 44, 850
# $ 98, 419
# $ 74,902
# SCHEDULE 3
# SCHEDULE OF EXPENSES - ALCOHOL RESEARCH CENTER
# Metabolic Unit
# $149, 960
# $123, 555
# Pilot Studies
# Intermural Research
# 16,520
# 10, 815
# -0-
# 5,000
# $166, 480
# $139,370
# *Reclassified to conform to current year's presentation.
# See Accountant's Report.
# -10-
#
# Questions:
# 1. What is the Expenses for Salaries for 1986?
# 2. What is the Expenses for Publications for 1987?
# 3. What is the Expenses for Publications for 1986?
# 4. What is the Expenses for Salaries for 1987?
# 5. What is the Expenses for Employee Benefits for 1987?
# 6. What is the Expenses for Employee Benefits for 1986?
# 7. What is the Expenses for Rent for 1987?
# 8. What is the Expenses for Rent for 1986?
# 9. What is the Expenses for legal for 1987?
# 10. What is the Expenses for legal for 1986?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# SCHEDULE 1
# ALCOHOLIC BEVERAGE MEDICAL RESEARCH FOUNDATION
# SCHEDULE OF ADMINISTRATION EXPENSES - HEADQUARTERS
# Year Ending December 31,
# 1987
# 1986*
# Salaries
# Travel, Including Public Trustees
# $117 , 047
# $123, 110
# Employee Benefits
# 29,928
# 18,559
# 21,844
# Publications
# 10 ,596
# 23,453
# 3,700
# Office Expenses
# 9,345
# Rent
# 9, 154
# 8,721
# 9, 020
# Legal
# 8,399
# 1 , 354
# Insurance
# 7,442
# Honoraria
# 7,000
# 6,792
# Accounting
# 7,000
# 6,459
# Meetings
# 6,348
# 4,536
# Service Fee
# 4,416
# 2,635
# Telephone
# 4,671
# 2,958
# Public Relations
# 2, 129
# -0-
# 14,383
# $235,839
# $235, 160
# SCHEDULE 2
# SCHEDULE OF EXPENSES - TECHNICAL SUPPORT
# Medical Intelligence
# $ 53,568
# Biostatistics
# $ 30, 052
# 44 ,851
# 44, 850
# $ 98, 419
# $ 74,902
# SCHEDULE 3
# SCHEDULE OF EXPENSES - ALCOHOL RESEARCH CENTER
# Metabolic Unit
# $149, 960
# $123, 555
# Pilot Studies
# Intermural Research
# 16,520
# 10, 815
# -0-
# 5,000
# $166, 480
# $139,370
# *Reclassified to conform to current year's presentation.
# See Accountant's Report.
# -10-
#
# Questions:
# 1. What is the Expenses for Salaries for 1986?
# 2. What is the Expenses for Publications for 1987?
# 3. What is the Expenses for Publications for 1986?
# 4. What is the Expenses for Salaries for 1987?
# 5. What is the Expenses for Employee Benefits for 1987?
# 6. What is the Expenses for Employee Benefits for 1986?
# 7. What is the Expenses for Rent for 1987?
# 8. What is the Expenses for Rent for 1986?
# 9. What is the Expenses for legal for 1987?
# 10. What is the Expenses for legal for 1986?
#
# Answers: ASSISTANT: 1. $117,047
# 2. $235,839
# 3. $123,110
# 4. $235,160
# 5. $18,559
# 6. $21,844
# 7. $9,345
# 8. $8,721
# 9. $1,354
# 10. $6,792
#
# [Document: fgbd0079_4]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# SENT BY:RJ REYNOLDS TOB. CO. ; 8- 9-94 ; 15:25 ;PT&D MECH & INST DEV-
# 9197410918;# 4
# . .: .
# CSF Run Sheet
# Date:
# PD- 5254 8
# CSF- 2-2Z
# Run Nos.
# 1883 - 1897
# Net Pounds Infeed:
# 893
# Net Pounds Out:
# 770
# 86
# 51441 8651
#
# Questions:
# 1. What is the PD ?
# 2. What is the CSF?
# 3. What is the Net Pound Infeed?
# 4. What is the Net Pounds Out ?
# 5. What is the heading of the document ?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# SENT BY:RJ REYNOLDS TOB. CO. ; 8- 9-94 ; 15:25 ;PT&D MECH & INST DEV-
# 9197410918;# 4
# . .: .
# CSF Run Sheet
# Date:
# PD- 5254 8
# CSF- 2-2Z
# Run Nos.
# 1883 - 1897
# Net Pounds Infeed:
# 893
# Net Pounds Out:
# 770
# 86
# 51441 8651
#
# Questions:
# 1. What is the PD ?
# 2. What is the CSF?
# 3. What is the Net Pound Infeed?
# 4. What is the Net Pounds Out ?
# 5. What is the heading of the document ?
#
# Answers: ASSISTANT: 1. PD is an abbreviation for "Pounds, Dry" which is a unit of weight.
# 2. CSF stands for "Cattle Sickness Fever".
# 3. The Net Pound Infeed is the amount of weight that is being fed to the cattle.
# 4. The Net Pounds Out is the amount of weight that has been lost by the cattle.
# 5. The heading of the document is "CSF Run Sheet".
#
# [Document: fgbd0079_7]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# SENT BY:RJ REYNOLDS TOB. CO. ; 8- 8-94 : 15:26 :PT&D MECH & INST DEV-
# 9197410918;# 7
# .. . . .
# .. . . .
# CSF Run Sheet
# Date:
# 7.28-94
# PD. 5760 C
# CSF- 72/
# Run Nos.
# 1934 - 1943
# Net Pounds Infeed: 584
# Net Pounds Out:_2/87
# 83.4%
# SEPARAT BINDER HYDRATION IN PULP PRIOR TO B-3
# 51441 8654
#
# Questions:
# 1. What is the PD?
# 2. What is the percentage of net pounds out over net pounds infeed (handwritten)?
# 3. What is the Net pounds Out?
# 4. What is the Net pounds Infeed?
# 5. What is the CSF?
# 6. What should be done prior to B-3?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# SENT BY:RJ REYNOLDS TOB. CO. ; 8- 8-94 : 15:26 :PT&D MECH & INST DEV-
# 9197410918;# 7
# .. . . .
# .. . . .
# CSF Run Sheet
# Date:
# 7.28-94
# PD. 5760 C
# CSF- 72/
# Run Nos.
# 1934 - 1943
# Net Pounds Infeed: 584
# Net Pounds Out:_2/87
# 83.4%
# SEPARAT BINDER HYDRATION IN PULP PRIOR TO B-3
# 51441 8654
#
# Questions:
# 1. What is the PD?
# 2. What is the percentage of net pounds out over net pounds infeed (handwritten)?
# 3. What is the Net pounds Out?
# 4. What is the Net pounds Infeed?
# 5. What is the CSF?
# 6. What should be done prior to B-3?
#
# Answers: ASSISTANT: 1. PD is short for "Pulp Density."
# 2. The percentage of net pounds out over net pounds infeed is 83.4%.
# 3. The Net pounds Out is 2/87.
# 4. The Net pounds Infeed is 584.
# 5. CSF stands for "Cystic Fibrosis."
# 6. Prior to B-3, the pulp should be hydrated in a separate binder.
#
# [Document: fgfl0228_4]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# Figure 2
# 400 t/d (as-received lignite). The unit is
# capable of handling feedstocks with up to
# SCGP performance
# 35% moisture, 30% ash and 4% sulphur
# Effect of different feedstocks
# at design gas production rates.
# Treated product gas will contain
# approximately 99% hydrogen and
# carbon monoxide (nitrogen-free basis),
# less than 160 ppm sulphur compounds,
# Dry gas
# Texas
# Rheinbraun Illinois
# W. Virginia
# Fluid coke
# and other minor trace components
# composition
# ignite
# brown coal
# No. 6
# (Pittsburgh
# (tar sands)
# Actual nitrogen content in the product
# (% volume)
# seam
# o/c
# gas will depend on whether nitrogen or
# another gas such as recycled product
# gas or carbon monoxide is used as coal
# H ,
# 32.4
# 28.6
# 30.5
# 31.7
# 22.3
# feed transport gas.
# CO
# 61.8
# 64.5
# 65 .1
# 64.3
# 70.9
# The Shell Deer Park Manufacturing
# Complex was chosen as the SCGP-1
# CO,
# 4.6
# 6.1
# 2.0
# 2.0
# 3.7
# ocation primarily because it can make
# CH
# use of the product gas. Also, some of the
# HS-COS
# 0.3
# 0.1
# 1.5
# 1.1
# 2.2
# utility requirements can be met by existing
# acilities.
# N + A
# 0.9
# 0.7
# 0.9
# 1.0
# 0.9
# Oxygen and nitrogen will be
# Cold gas
# 81
# 78
# 81
# 81
# 80
# purchased. Slag and fly slag produced
# efficiency*
# will be used for road building and other
# applications, while acid gas will be sent to
# the Deer Park Complex sulphur plant.
# Stripped effluent and storm water will be
# sent to the Complex effluent treating
# system.
# *Energy recovered from the coal in the synthesis gas
# Slip stream units
# Most of the ash in the coal is transformed
# into a vitreous non-leachable solid which
# At approximately one-fifth the
# The SCGP-1 acid gas removal system is
# anticipated initial commercial module
# designed to meet very strict environmental
# s suitable as a construction material.
# regulations. A gas treating slip stream unit
# Process water can be readily cleaned and
# size, SCGP-1 is the most efficient route to
# commercialisation of the process. It is
# will be installed and operated as part of
# discharged.
# much less costly to construct and operate
# the overall programme. Effluent water slip
# than a full-scale unit and provides the
# stream units will also be included.
# opportunity to test process optimisations
# Properly designed slip stream units
# operating on SCGP-1 product streams
# Demonstration
# more readily. The maximum scale-up
# factor of five for any given piece of
# are cost-effective methods of testing
# equipment is well within Shell capabilities,
# options and acquiring data necessary to
# plant
# the lower limit on size was actually set by a
# design commercial plants with varying
# requirement to demonstrate equipment
# environmental constraints and product
# and configurations that would be
# gas uses.
# employed commercially. Many of the
# components will require little or no scaling.
# Participants
# The SCGP-1 demonstration plant in
# Combustion Engineering's subsidiary
# Houston will confirm equipment life and
# The unit will include coal receiving and
# preparation facilities, a high-pressure
# Lummus Crest and the Electric Power
# the scale-up information necessary for
# commercial design. Environmental design
# gasifier with high-temperature energy
# Research Institute (EPRI) are jointly
# participating with Shell companies in the
# data for potential commercial feedstocks
# recovery, solids removal, and gas and
# water treating to provide both clean
# design, construction and operation of
# will also be acquired. SCGP-1 includes
# medium- BTU gas for power generation
# SCGP-1. Lummus Crest will provide
# equipment for demonstrating several
# process optimisations. These will increase
# and high-value steam. The unit is
# scheduled for start-up in the first half of
# engineering design and procurement
# stream factor and system reliability, and
# 1987.
# services. EPRI will provide an electric utility
# industry perspective. Shell Internationale
# reduce capital and operating costs.
# A final objective for SCGP-1 is to move
# SCGP-1 is designed to gasify feeds
# Petroleum, Shell Internationale Research,
# from lignites to bituminous coals. In
# Deutsche Shell, Shell Oil and Shell
# further along the experience curve, in part
# by developing an experienced operating
# principle, other feeds, such as petroleum
# team and extensive operating know-how,
# coke, could also be gasified. Feeds will
# Development provided the process
# normally be received by train or truck and
# design and much of the engineering
# which will be readily transferable to the
# gasified at rates of about 250 t/d
# design information, and will operate and
# first commercial plant.
# (as-received Illinois high sulphur coal) to
# manage the unit and experimental
# programme
# Source: https://www.industrydocuments.ucsf.edu/docs/fgfl0228
#
# Questions:
# 1. What is the figure number?
# 2. What is the footnote of the table in fig. 2?
# 3. What type of plant is SCGP 1?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# Figure 2
# 400 t/d (as-received lignite). The unit is
# capable of handling feedstocks with up to
# SCGP performance
# 35% moisture, 30% ash and 4% sulphur
# Effect of different feedstocks
# at design gas production rates.
# Treated product gas will contain
# approximately 99% hydrogen and
# carbon monoxide (nitrogen-free basis),
# less than 160 ppm sulphur compounds,
# Dry gas
# Texas
# Rheinbraun Illinois
# W. Virginia
# Fluid coke
# and other minor trace components
# composition
# ignite
# brown coal
# No. 6
# (Pittsburgh
# (tar sands)
# Actual nitrogen content in the product
# (% volume)
# seam
# o/c
# gas will depend on whether nitrogen or
# another gas such as recycled product
# gas or carbon monoxide is used as coal
# H ,
# 32.4
# 28.6
# 30.5
# 31.7
# 22.3
# feed transport gas.
# CO
# 61.8
# 64.5
# 65 .1
# 64.3
# 70.9
# The Shell Deer Park Manufacturing
# Complex was chosen as the SCGP-1
# CO,
# 4.6
# 6.1
# 2.0
# 2.0
# 3.7
# ocation primarily because it can make
# CH
# use of the product gas. Also, some of the
# HS-COS
# 0.3
# 0.1
# 1.5
# 1.1
# 2.2
# utility requirements can be met by existing
# acilities.
# N + A
# 0.9
# 0.7
# 0.9
# 1.0
# 0.9
# Oxygen and nitrogen will be
# Cold gas
# 81
# 78
# 81
# 81
# 80
# purchased. Slag and fly slag produced
# efficiency*
# will be used for road building and other
# applications, while acid gas will be sent to
# the Deer Park Complex sulphur plant.
# Stripped effluent and storm water will be
# sent to the Complex effluent treating
# system.
# *Energy recovered from the coal in the synthesis gas
# Slip stream units
# Most of the ash in the coal is transformed
# into a vitreous non-leachable solid which
# At approximately one-fifth the
# The SCGP-1 acid gas removal system is
# anticipated initial commercial module
# designed to meet very strict environmental
# s suitable as a construction material.
# regulations. A gas treating slip stream unit
# Process water can be readily cleaned and
# size, SCGP-1 is the most efficient route to
# commercialisation of the process. It is
# will be installed and operated as part of
# discharged.
# much less costly to construct and operate
# the overall programme. Effluent water slip
# than a full-scale unit and provides the
# stream units will also be included.
# opportunity to test process optimisations
# Properly designed slip stream units
# operating on SCGP-1 product streams
# Demonstration
# more readily. The maximum scale-up
# factor of five for any given piece of
# are cost-effective methods of testing
# equipment is well within Shell capabilities,
# options and acquiring data necessary to
# plant
# the lower limit on size was actually set by a
# design commercial plants with varying
# requirement to demonstrate equipment
# environmental constraints and product
# and configurations that would be
# gas uses.
# employed commercially. Many of the
# components will require little or no scaling.
# Participants
# The SCGP-1 demonstration plant in
# Combustion Engineering's subsidiary
# Houston will confirm equipment life and
# The unit will include coal receiving and
# preparation facilities, a high-pressure
# Lummus Crest and the Electric Power
# the scale-up information necessary for
# commercial design. Environmental design
# gasifier with high-temperature energy
# Research Institute (EPRI) are jointly
# participating with Shell companies in the
# data for potential commercial feedstocks
# recovery, solids removal, and gas and
# water treating to provide both clean
# design, construction and operation of
# will also be acquired. SCGP-1 includes
# medium- BTU gas for power generation
# SCGP-1. Lummus Crest will provide
# equipment for demonstrating several
# process optimisations. These will increase
# and high-value steam. The unit is
# scheduled for start-up in the first half of
# engineering design and procurement
# stream factor and system reliability, and
# 1987.
# services. EPRI will provide an electric utility
# industry perspective. Shell Internationale
# reduce capital and operating costs.
# A final objective for SCGP-1 is to move
# SCGP-1 is designed to gasify feeds
# Petroleum, Shell Internationale Research,
# from lignites to bituminous coals. In
# Deutsche Shell, Shell Oil and Shell
# further along the experience curve, in part
# by developing an experienced operating
# principle, other feeds, such as petroleum
# team and extensive operating know-how,
# coke, could also be gasified. Feeds will
# Development provided the process
# normally be received by train or truck and
# design and much of the engineering
# which will be readily transferable to the
# gasified at rates of about 250 t/d
# design information, and will operate and
# first commercial plant.
# (as-received Illinois high sulphur coal) to
# manage the unit and experimental
# programme
# Source: https://www.industrydocuments.ucsf.edu/docs/fgfl0228
#
# Questions:
# 1. What is the figure number?
# 2. What is the footnote of the table in fig. 2?
# 3. What type of plant is SCGP 1?
#
# Answers: ASSISTANT: 1. 2
# 2. 1
# 3. Demonstration
#
# [Document: fggn0226_48]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# JOHNSON & JOHNSON AND SUBSIDIARIES
# CONSOLIDATED STATEMENTS OF EARNINGS
# (Dollars in Millions Except Per Share Figures) (Note 1)
# 2010
# 2009
# 2008
# Sales to customers
# $ 61.587
# 61,897
# 63,747
# Cost of products sold
# 18,792
# 18,447
# 18,511
# Gross profit
# 4 795 43,450 45,236
# Selling, marketing and administrative expenses
# 19,424
# 19,801
# 21,490
# Research and development expense
# Purchased in-process research and development (Note 20)
# 6,844 6,986 7,577
# 181
# Interest income
# (107) (90) (361)
# Interest expense, net of portion capitalized (Note 4)
# 45.
# 451
# 435
# Other (income) expense, net (768) (526) (1,015)
# Restructuring (Note 22)
# 1,073
# Earnings before provision for taxes on income
# 16,947 15,755 16,929
# Provision for taxes on income (Note 8)
# 3,613
# Net earnings
# 3,489
# 3,980
# $ 13,334
# 12,266
# 12,949
# Basic net earnings per share (Notes 1 and 15)
# $
# 4.85
# 4.45
# 4.62
# Diluted net earnings per share (Notes 1 and 15)
# $ 4.78 4.40 4.57
# Cash dividends per share
# 1.930
# 1.795
# Basic average shares outstanding (Notes 1 and 15)
# Diluted average shares outstanding (Notes 1 and 15)
# 2,751.4 2,759.5 2,802.5
# 2,788.8
# 2,789.1
# 2,835.6
# See Notes to Consolidated Financial Statements
# 42
# JOHNSON & JOHNSON 2010 ANNUAL REPORT
# Source: https://www.industrydocuments.ucsf.edu/docs/fggn0226
# P-08504-00048
#
# Questions:
# 1. what is the 'sales to customers' in 2010?
# 2. What is the 'net earnings' for the year 2009?
# 3. What is the name of the company mentioned at the top of the page?
# 4. what was the amount incurred for 'restructuring' in 2009?
# 5. Which year shows a higher 'gross profit' ?
# 6. How much was the 'research and development expense' for the year 2009?
# 7. how much did the company earn in 2010 in terms of 'gross profits'?
# 8. What is the year of 'Annual Report' mentioned at the bottom right of the statement?
# 9. which year shows a higher 'diluted average shares outstanding' when compared to 2009?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# JOHNSON & JOHNSON AND SUBSIDIARIES
# CONSOLIDATED STATEMENTS OF EARNINGS
# (Dollars in Millions Except Per Share Figures) (Note 1)
# 2010
# 2009
# 2008
# Sales to customers
# $ 61.587
# 61,897
# 63,747
# Cost of products sold
# 18,792
# 18,447
# 18,511
# Gross profit
# 4 795 43,450 45,236
# Selling, marketing and administrative expenses
# 19,424
# 19,801
# 21,490
# Research and development expense
# Purchased in-process research and development (Note 20)
# 6,844 6,986 7,577
# 181
# Interest income
# (107) (90) (361)
# Interest expense, net of portion capitalized (Note 4)
# 45.
# 451
# 435
# Other (income) expense, net (768) (526) (1,015)
# Restructuring (Note 22)
# 1,073
# Earnings before provision for taxes on income
# 16,947 15,755 16,929
# Provision for taxes on income (Note 8)
# 3,613
# Net earnings
# 3,489
# 3,980
# $ 13,334
# 12,266
# 12,949
# Basic net earnings per share (Notes 1 and 15)
# $
# 4.85
# 4.45
# 4.62
# Diluted net earnings per share (Notes 1 and 15)
# $ 4.78 4.40 4.57
# Cash dividends per share
# 1.930
# 1.795
# Basic average shares outstanding (Notes 1 and 15)
# Diluted average shares outstanding (Notes 1 and 15)
# 2,751.4 2,759.5 2,802.5
# 2,788.8
# 2,789.1
# 2,835.6
# See Notes to Consolidated Financial Statements
# 42
# JOHNSON & JOHNSON 2010 ANNUAL REPORT
# Source: https://www.industrydocuments.ucsf.edu/docs/fggn0226
# P-08504-00048
#
# Questions:
# 1. what is the 'sales to customers' in 2010?
# 2. What is the 'net earnings' for the year 2009?
# 3. What is the name of the company mentioned at the top of the page?
# 4. what was the amount incurred for 'restructuring' in 2009?
# 5. Which year shows a higher 'gross profit' ?
# 6. How much was the 'research and development expense' for the year 2009?
# 7. how much did the company earn in 2010 in terms of 'gross profits'?
# 8. What is the year of 'Annual Report' mentioned at the bottom right of the statement?
# 9. which year shows a higher 'diluted average shares outstanding' when compared to 2009?
#
# Answers: ASSISTANT: 1. $61.587
# 2. $12.949
# 3. Johnson & Johnson
# 4. $1,073
# 5. 2008
# 6. $6,844
# 7. $13,334
# 8. 2010
# 9. 2010
#
# [Document: fggn0226_77]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# A summary of option activity under the Plan as of January 2, 2011, January 3, 2010 and December 28, 2008 and changes
# during the years ending on those dates is presented below:
# Aggregate
# Intrinsic
# Weighted
# Value
# Outstanding
# Dollars in
# (Shares in Thousands)
# Shares
# Average
# Exercise Price
# Millions)
# Shares at December 30, 2007
# 228.629 $ 56.83
# $ 2.411
# Options granted
# 22,428
# 61.80
# Options exercised
# (50.035) 30.27
# Options canceled/forfeited
# (5,525
# 61.90
# Shares at December 28, 2008
# 215,499
# 58.14
# $ 597
# Options granted
# 21,576
# 58.32
# Options exercised (18,22)) 50.97
# Options canceled/forfeited
# (6,131)
# 61.85
# Shares at January 3. 2010 212,719
# 58.66 $ 1,310
# Options granted
# 13,996
# 62.62
# Options exercised(25,020) 51.84
# Options canceled/forfeited
# (8,005
# 62.36
# Shares at January 2, 201 1 193,690
# $ 59.68
# $ 648
# The total intrinsic value of options exercised was $278 million, $184 million and $506 million in 2010, 2009 and 2008,
# respectively.
# The following table summarizes stock options outstanding and exercisable at January 2, 2011:
# (Shares in Thousands)
# Outstanding
# Exercisable
# Average
# Average
# Exercise
# Average Exercise
# Exercise
# Price Range
# Options
# Life (1)
# Price
# Options
# Price
# $25.00-$40.08
# 50 09 $2953 50 $ 29.53
# $41.26-$49.86
# 532
# 0.5
# 47.43
# 532
# 47.43
# $50.52-$52.80
# 20,155 2.1 52.20 20,115 52.20
# $53.00-$53.93
# 24,114
# 3.0 53.93
# 24,114
# 53.93
# $54.04-$57.30
# 24.332 1.1 57.28
# $57.44-$58.34
# 24,332
# 39,343
# 57.28
# 6.5
# 58.33
# 20, 175
# 58.33
# $58.42-$65.10
# 33,020 7.8 62.11 1,147 61.21
# $65.62-$68.37
# 52,144
# 4.8 65.97
# 50,810 65.98
# 193,690
# 4.7 $ 59.68 141,275 $ 59.25
# (1) Average contractual life remaining in years.
# Stock options exercisable at January 3, 2010 and December 28, 2008 were 148,349 at an average price of $57.26 and an
# average life of 5.0 years and 144,962 at an average price of $56.25 and an average life of 5.3 years, respectively.
# Restricted Share Units
# The Company grants restricted share units with a vesting period of three years. The Company settles employee stock issuances
# with treasury shares. Treasury shares are replenished throughout the year for the number of shares used for employee stock
# issuances.
# A summary of share activity under the Plan as of January 2, 2011:
# Outstanding
# (Shares in Thousands
# Shares
# Shares at December 30.207
# 13,661
# Granted
# Issued (40)
# 10, 105
# Canceled/forfeited
# (1,468)
# Shares at December 28, 200822,258
# Granted
# 11,172
# Issued
# (5,714)
# Canceled/forfeited
# (1,392
# Shares at January 3, 2010
# 26.324
# Granted
# 12,003
# P-08504-00077
# Source: https://www.industrydocuments.ucsf.edu/docs/fggn0226
#
# Questions:
# 1. What is the total intrinsic value of options exercised in 2010?
# 2. What is the total intrinsic value of options exercised in 2009?
# 3. What is the total intrinsic value of options exercised in 2008?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# A summary of option activity under the Plan as of January 2, 2011, January 3, 2010 and December 28, 2008 and changes
# during the years ending on those dates is presented below:
# Aggregate
# Intrinsic
# Weighted
# Value
# Outstanding
# Dollars in
# (Shares in Thousands)
# Shares
# Average
# Exercise Price
# Millions)
# Shares at December 30, 2007
# 228.629 $ 56.83
# $ 2.411
# Options granted
# 22,428
# 61.80
# Options exercised
# (50.035) 30.27
# Options canceled/forfeited
# (5,525
# 61.90
# Shares at December 28, 2008
# 215,499
# 58.14
# $ 597
# Options granted
# 21,576
# 58.32
# Options exercised (18,22)) 50.97
# Options canceled/forfeited
# (6,131)
# 61.85
# Shares at January 3. 2010 212,719
# 58.66 $ 1,310
# Options granted
# 13,996
# 62.62
# Options exercised(25,020) 51.84
# Options canceled/forfeited
# (8,005
# 62.36
# Shares at January 2, 201 1 193,690
# $ 59.68
# $ 648
# The total intrinsic value of options exercised was $278 million, $184 million and $506 million in 2010, 2009 and 2008,
# respectively.
# The following table summarizes stock options outstanding and exercisable at January 2, 2011:
# (Shares in Thousands)
# Outstanding
# Exercisable
# Average
# Average
# Exercise
# Average Exercise
# Exercise
# Price Range
# Options
# Life (1)
# Price
# Options
# Price
# $25.00-$40.08
# 50 09 $2953 50 $ 29.53
# $41.26-$49.86
# 532
# 0.5
# 47.43
# 532
# 47.43
# $50.52-$52.80
# 20,155 2.1 52.20 20,115 52.20
# $53.00-$53.93
# 24,114
# 3.0 53.93
# 24,114
# 53.93
# $54.04-$57.30
# 24.332 1.1 57.28
# $57.44-$58.34
# 24,332
# 39,343
# 57.28
# 6.5
# 58.33
# 20, 175
# 58.33
# $58.42-$65.10
# 33,020 7.8 62.11 1,147 61.21
# $65.62-$68.37
# 52,144
# 4.8 65.97
# 50,810 65.98
# 193,690
# 4.7 $ 59.68 141,275 $ 59.25
# (1) Average contractual life remaining in years.
# Stock options exercisable at January 3, 2010 and December 28, 2008 were 148,349 at an average price of $57.26 and an
# average life of 5.0 years and 144,962 at an average price of $56.25 and an average life of 5.3 years, respectively.
# Restricted Share Units
# The Company grants restricted share units with a vesting period of three years. The Company settles employee stock issuances
# with treasury shares. Treasury shares are replenished throughout the year for the number of shares used for employee stock
# issuances.
# A summary of share activity under the Plan as of January 2, 2011:
# Outstanding
# (Shares in Thousands
# Shares
# Shares at December 30.207
# 13,661
# Granted
# Issued (40)
# 10, 105
# Canceled/forfeited
# (1,468)
# Shares at December 28, 200822,258
# Granted
# 11,172
# Issued
# (5,714)
# Canceled/forfeited
# (1,392
# Shares at January 3, 2010
# 26.324
# Granted
# 12,003
# P-08504-00077
# Source: https://www.industrydocuments.ucsf.edu/docs/fggn0226
#
# Questions:
# 1. What is the total intrinsic value of options exercised in 2010?
# 2. What is the total intrinsic value of options exercised in 2009?
# 3. What is the total intrinsic value of options exercised in 2008?
#
# Answers: ASSISTANT: 1. The total intrinsic value of options exercised in 2010 was $278 million.
# 2. The total intrinsic value of options exercised in 2009 was $184 million.
# 3. The total intrinsic value of options exercised in 2008 was $506 million.
#
# [Document: fgkw0228_4]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# Page 2
# October 13, 1993
# If you need any additional information regarding the budget, please do not
# hesitate to contact us.
# Sincerely,
# Attila G. Devenyi, M D
# Chief, Division of Pediatric
# Gastroenterology and Nutrition
# Coleen P Greecher, M.S., R.D.
# Assistant Professor, Surgery, and Pediatrics
# AGD/pr
# cc
# Margaret Petruska, Program Office
# Howard Heinz Endowment
# Call; I Mad Entrance
#
# Questions:
# 1. What is the page number?
# 2. Regarding what can they ask additional information on?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# Page 2
# October 13, 1993
# If you need any additional information regarding the budget, please do not
# hesitate to contact us.
# Sincerely,
# Attila G. Devenyi, M D
# Chief, Division of Pediatric
# Gastroenterology and Nutrition
# Coleen P Greecher, M.S., R.D.
# Assistant Professor, Surgery, and Pediatrics
# AGD/pr
# cc
# Margaret Petruska, Program Office
# Howard Heinz Endowment
# Call; I Mad Entrance
#
# Questions:
# 1. What is the page number?
# 2. Regarding what can they ask additional information on?
#
# Answers: ASSISTANT: 1. Page 2
# 2. The budget
#
# [Document: fglc0003_1]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# JENI BY:
# : - 4-09 : 8:02 :
# 9107471657-
# ik -feet
# KJK Employes Counseling
# Reynolds Bide. - And Ploor (10207)
# May 3, 1905
# Maura Payno-Elliy
# Public Relations - External
# FAX: $10/741-080
# EXCHANGE VISI
# NORTH CAROLINA CENTER FOR INTERNATIONAL UNDERSTANDING (NCGIU)
# JUNE 23 - 29. 1095."
# OF DEL SOATION FROM BOER, HUNGARY TO WINSTON-SALEM
# 30 - 38 PERSONS
# WOULD LIKE TO RECEIVE GIFT PRODUCTS BY MAY.10
# Aminimum of thirty delegates from Eger, Hungary. will be arriving
# m Winston-Balem on
# June 23. 1995, and will be staying by Homes of many of the family members who visited Eger
# and Budapest, Hunanry. Last Ju
# for Internation
# rnational Understanding.
# The exchange is sponsored by the North Carolina Center
# NCCIU would like to begin assembling the gift packages no later than May 10. 1995.
# Our preference Is for the following R.I Reynolds Tobacco products:
# Key Chima
# 4 cartons
# Winsons
# Sulomm
# Camel
# other brands
# You may nibethute as appropriate. Please confirm.
# With appreciation.
# Roday C. Brown
# Phone 741-5010 or 5033
# copy: Mrs. Anne Loister, Chair
# NCCTU Hungarian Exchange
# 640 Nokomis Court_
# Winston-salem. NC 27104
# TRANSMISSION REPORT
# THIS DOCUMENT WAS CONFIRMED
# ( REDUCED SAMPLE ABOVE - SEE DETAILS BELOW )
# *** COUNT **
# TOTAL PAGES SCANNED
# TOTAL PAGES CONFIRMED
# . .
# No.
# REMOTE STATION
# START TIME
# DURATION #PAGES
# MODE
# RESULTS
# 910741 1061
# 5- 8-95
# 11 :22
# 0'39'
# COMPLETED
# 9600
# NOTE
# TOTAL
# 0:00 39'
# I'D
# No. : OPERATION NUMBER
# POLLED BY REMOTE
# SF
# 3: 4800BPS SELECTED EC
# PG
# STORE & FORWARD
# ERROR CORRECT
# MB : SEND TO MAILBOX
# POLLING A REMOTE
# RI
# MP>
# RELAY INITIATE
# G2
# MULTI - POLLING
# RS
# : G2 COMMUNICATION
# RM
# RELAY STATION
# RECEIV
# 51272 0885
# Source: https://www.industrydocuments.ucsf.edu/docs/fglc0003
#
# Questions:
# 1. What is the full form for NCCIU?
# 2. Where are the delegates coming from?
# 3. What date should the gift products be received by?
# 4. What is the total pages scanned?
# 5. What does EC stand for?
# 6. How many cartons of Camels should the gift package contain?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# JENI BY:
# : - 4-09 : 8:02 :
# 9107471657-
# ik -feet
# KJK Employes Counseling
# Reynolds Bide. - And Ploor (10207)
# May 3, 1905
# Maura Payno-Elliy
# Public Relations - External
# FAX: $10/741-080
# EXCHANGE VISI
# NORTH CAROLINA CENTER FOR INTERNATIONAL UNDERSTANDING (NCGIU)
# JUNE 23 - 29. 1095."
# OF DEL SOATION FROM BOER, HUNGARY TO WINSTON-SALEM
# 30 - 38 PERSONS
# WOULD LIKE TO RECEIVE GIFT PRODUCTS BY MAY.10
# Aminimum of thirty delegates from Eger, Hungary. will be arriving
# m Winston-Balem on
# June 23. 1995, and will be staying by Homes of many of the family members who visited Eger
# and Budapest, Hunanry. Last Ju
# for Internation
# rnational Understanding.
# The exchange is sponsored by the North Carolina Center
# NCCIU would like to begin assembling the gift packages no later than May 10. 1995.
# Our preference Is for the following R.I Reynolds Tobacco products:
# Key Chima
# 4 cartons
# Winsons
# Sulomm
# Camel
# other brands
# You may nibethute as appropriate. Please confirm.
# With appreciation.
# Roday C. Brown
# Phone 741-5010 or 5033
# copy: Mrs. Anne Loister, Chair
# NCCTU Hungarian Exchange
# 640 Nokomis Court_
# Winston-salem. NC 27104
# TRANSMISSION REPORT
# THIS DOCUMENT WAS CONFIRMED
# ( REDUCED SAMPLE ABOVE - SEE DETAILS BELOW )
# *** COUNT **
# TOTAL PAGES SCANNED
# TOTAL PAGES CONFIRMED
# . .
# No.
# REMOTE STATION
# START TIME
# DURATION #PAGES
# MODE
# RESULTS
# 910741 1061
# 5- 8-95
# 11 :22
# 0'39'
# COMPLETED
# 9600
# NOTE
# TOTAL
# 0:00 39'
# I'D
# No. : OPERATION NUMBER
# POLLED BY REMOTE
# SF
# 3: 4800BPS SELECTED EC
# PG
# STORE & FORWARD
# ERROR CORRECT
# MB : SEND TO MAILBOX
# POLLING A REMOTE
# RI
# MP>
# RELAY INITIATE
# G2
# MULTI - POLLING
# RS
# : G2 COMMUNICATION
# RM
# RELAY STATION
# RECEIV
# 51272 0885
# Source: https://www.industrydocuments.ucsf.edu/docs/fglc0003
#
# Questions:
# 1. What is the full form for NCCIU?
# 2. Where are the delegates coming from?
# 3. What date should the gift products be received by?
# 4. What is the total pages scanned?
# 5. What does EC stand for?
# 6. How many cartons of Camels should the gift package contain?
#
# Answers: ASSISTANT: 1. NCCIU stands for North Carolina Center for International Understanding.
# 2. The delegates are coming from Eger, Hungary.
# 3. The gift products should be received by May 10, 1995.
# 4. The total pages scanned is 39.
# 5. EC stands for Exchange Communication.
# 6. The gift package should contain 4 cartons of Camels.
#
# [Document: fgmx0225_5]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# SCOPE & FEASIBILITY
# (INPUT TO GATE 2)
# THIS PAGE IS REQUIRED IF QUALITATIVE RESEARCH IS CONDUCTED
# TYPE OF RESEARCH CONDUCTED:
# 0000 * 0
# Internal Focus Groups
# Consumer Focus Groups
# Consumer Panel
# Online Qualitative
# Online Quantitative
# OTHER (DESCRIBE)
# PRODUCT CONCEPT TESTED:
# Explain how the concept was presented to those tested (visual attachments can be included):
# Consumer workshops with approx 8 respondents and duration of 2 12 hours per group Recruit 12
# to get 8 respondents
# Age: 21-29 years of adult smokers; (50% between 21-25 years old)
# Ethnic: 50% Caucasians, 50% mix of others
# Education: all levels
# Personal income: Annual salary of $20 000+
# Living: Preference for adult smokers who live in their own flat/house
# Working: All respondents work at least 20 hours a week. (Except 3 non working students per
# group)
# Attitude: all respondents with good verbal skills and a pleasure oriented lifestyle
# Evaluation of the impact on the KOOL brand perception if the current packaging design would be
# changed. Inputs to the brand communication on the pack: 00s, KOOL.
# 1 focus groups (female), with regular adult smokers of menthol brands (stand alones and line
# extension menthol brands
# 50% adult Newport smokers
# 50% adult smokers of Marlboro menthol
# 1 focus groups (male), with regular adult smokers of Newport
# 2 focus groups (1 female, 1 male) with adult occasional menthol smokers
# 50% adult Newport smokers
# 50% adult smokers of Marlboro menthol
# 2 focus groups (mixed gender) with adult KOOL smokers
# 1 group with regular adult KOOL smokers
# 1 group with adult occasional KOOL smokers (regular brand: normal tobacco
# LEARNING RESULTS:
# Every effort should be made to gather these pieces of information, so a consistent evaluation occurs across
# projects:
# Mean Rating (10-pt scale)
# Appeal
# Importance
# Concept
# - Product
# - Packaging
# 5
# 54611 2770
# Source: https://www.industrydocuments.ucsf.edu/docs/fgmx0225
#
# Questions:
# 1. What type of research is conducted?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# SCOPE & FEASIBILITY
# (INPUT TO GATE 2)
# THIS PAGE IS REQUIRED IF QUALITATIVE RESEARCH IS CONDUCTED
# TYPE OF RESEARCH CONDUCTED:
# 0000 * 0
# Internal Focus Groups
# Consumer Focus Groups
# Consumer Panel
# Online Qualitative
# Online Quantitative
# OTHER (DESCRIBE)
# PRODUCT CONCEPT TESTED:
# Explain how the concept was presented to those tested (visual attachments can be included):
# Consumer workshops with approx 8 respondents and duration of 2 12 hours per group Recruit 12
# to get 8 respondents
# Age: 21-29 years of adult smokers; (50% between 21-25 years old)
# Ethnic: 50% Caucasians, 50% mix of others
# Education: all levels
# Personal income: Annual salary of $20 000+
# Living: Preference for adult smokers who live in their own flat/house
# Working: All respondents work at least 20 hours a week. (Except 3 non working students per
# group)
# Attitude: all respondents with good verbal skills and a pleasure oriented lifestyle
# Evaluation of the impact on the KOOL brand perception if the current packaging design would be
# changed. Inputs to the brand communication on the pack: 00s, KOOL.
# 1 focus groups (female), with regular adult smokers of menthol brands (stand alones and line
# extension menthol brands
# 50% adult Newport smokers
# 50% adult smokers of Marlboro menthol
# 1 focus groups (male), with regular adult smokers of Newport
# 2 focus groups (1 female, 1 male) with adult occasional menthol smokers
# 50% adult Newport smokers
# 50% adult smokers of Marlboro menthol
# 2 focus groups (mixed gender) with adult KOOL smokers
# 1 group with regular adult KOOL smokers
# 1 group with adult occasional KOOL smokers (regular brand: normal tobacco
# LEARNING RESULTS:
# Every effort should be made to gather these pieces of information, so a consistent evaluation occurs across
# projects:
# Mean Rating (10-pt scale)
# Appeal
# Importance
# Concept
# - Product
# - Packaging
# 5
# 54611 2770
# Source: https://www.industrydocuments.ucsf.edu/docs/fgmx0225
#
# Questions:
# 1. What type of research is conducted?
#
# Answers: ASSISTANT: 1. Internal Focus Groups
#
# [Document: fgvc0225_9]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# R. J. Reynolds Tobacco Company
# Attachment 1
# 20 / Burley Grower Profile
# Page / of /
# PLEASE PRINT
# Individual or Corporate Name:
# Joseph Buss
# Effective Date :
# 4- 24-01
# Social Security or Tax ID No.
# PERSONAL/CONFIDENTIAL MATERIAL REDACTED
# Mailing Address
# 10. Box 332
# Irrigation:
# Yes
# No
# City
# Buds Spring
# State
# Virginia
# Zip Code Ly 3412
# Delivery Point
# Southwest Whse
# Home Telephone No.
# 540- 429-57/6
# Abingdon Va.
# Cellular Telephone No.
# Fax Telephone No.
# E-Mail Address
# Contract for Prior
# Contract for Current
# Contract for Total
# Crop Carryover Lbs
# Crop Lbs.
# Quota Lbs.
# 12 Digit Marketing Card Number
# Farm Address
# City
# State
# Owned
# Leased
# Owned
# Leased
# Owned
# Leased
# 51 1910000 105
# SAmC
# SAme
# 6/6
# 5 2 2
# LIEN HOLDER DATA
# Payee Name
# Payee Address
# Payee City
# State
# Zip Code
# Pay Percent %
# ") Joseph Russ
# SAME
# 100
# 2 )
# 3)
# 4
# 5)
# Percent Total (100%)
# Payees may be changed at delivery point during the season. Advise Delivery point upon arrival.
# PLEASE COMPLETE SEPARATE GROWER PROFILE FOR EACH FARM
# Grower Signature
# RJRT Representative Signature
# 52381 9100
# Source: https://www.industry?iscumm
# edintents.ucsf.edu/docs/fgvc0225
#
# Questions:
# 1. what is the individual or corporate name?
# 2. what is the effective date on the profile?
# 3. what is the mailing address of the individual?
# 4. what is the zipcode?
# 5. what is home telephone number of the individual?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# R. J. Reynolds Tobacco Company
# Attachment 1
# 20 / Burley Grower Profile
# Page / of /
# PLEASE PRINT
# Individual or Corporate Name:
# Joseph Buss
# Effective Date :
# 4- 24-01
# Social Security or Tax ID No.
# PERSONAL/CONFIDENTIAL MATERIAL REDACTED
# Mailing Address
# 10. Box 332
# Irrigation:
# Yes
# No
# City
# Buds Spring
# State
# Virginia
# Zip Code Ly 3412
# Delivery Point
# Southwest Whse
# Home Telephone No.
# 540- 429-57/6
# Abingdon Va.
# Cellular Telephone No.
# Fax Telephone No.
# E-Mail Address
# Contract for Prior
# Contract for Current
# Contract for Total
# Crop Carryover Lbs
# Crop Lbs.
# Quota Lbs.
# 12 Digit Marketing Card Number
# Farm Address
# City
# State
# Owned
# Leased
# Owned
# Leased
# Owned
# Leased
# 51 1910000 105
# SAmC
# SAme
# 6/6
# 5 2 2
# LIEN HOLDER DATA
# Payee Name
# Payee Address
# Payee City
# State
# Zip Code
# Pay Percent %
# ") Joseph Russ
# SAME
# 100
# 2 )
# 3)
# 4
# 5)
# Percent Total (100%)
# Payees may be changed at delivery point during the season. Advise Delivery point upon arrival.
# PLEASE COMPLETE SEPARATE GROWER PROFILE FOR EACH FARM
# Grower Signature
# RJRT Representative Signature
# 52381 9100
# Source: https://www.industry?iscumm
# edintents.ucsf.edu/docs/fgvc0225
#
# Questions:
# 1. what is the individual or corporate name?
# 2. what is the effective date on the profile?
# 3. what is the mailing address of the individual?
# 4. what is the zipcode?
# 5. what is home telephone number of the individual?
#
# Answers: ASSISTANT: 1. Joseph Buss
# 2. 4-24-01
# 3. 10. Box 332 Irrigation: Yes
# 4. Ly 3412
# 5. 540-429-57/6 Abingdon Va.
# 6. 51 1910000 105
#
# [Document: fgvh0227_91]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# Table 516
# Number of Participants Currently Considered Lost
# to Follow-up, by Clinical Center
# Number of Participants Lost to Follow-up
# Clinical Center
# SI
# UC
# Total
# A-Baltimore
# B-New York
# C-Minneapolis
# D-San Francisco
# E-St. Louis
# F-Boston Harvard
# G-Davis
# H-Chicago-Northwestern
# I-Chicago St. Joseph
# J-University of Chicago
# K-Portland
# L-Boston University
# M-Dayton
# N-Newark
# 0-Philadelphia
# P-Birmingham
# Q-Pittsburgh
# R-Chicago-Rush
# S-Rutgers
# T-Columbia
# U-Los Angeles
# V-Miami
# WUOHHOOHOOOHOOHH HOHOWO
# All Clinics Combined
# 19
# IWAOHOOHOOHOH HOOHOOOOWO
# U ODONHOHHOHONHOHNHOHOMC
# Source: https://www.industrydocuments.ucsf.edu/docs/fgvh0227
#
# Questions:
# 1. What is the table number?
# 2. Which is clinical center A ?
# 3. What is the no.of UC participants lost to follow-up in New York?
# 4. What is the total number of participants lost to follow-up in Baltimore?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# Table 516
# Number of Participants Currently Considered Lost
# to Follow-up, by Clinical Center
# Number of Participants Lost to Follow-up
# Clinical Center
# SI
# UC
# Total
# A-Baltimore
# B-New York
# C-Minneapolis
# D-San Francisco
# E-St. Louis
# F-Boston Harvard
# G-Davis
# H-Chicago-Northwestern
# I-Chicago St. Joseph
# J-University of Chicago
# K-Portland
# L-Boston University
# M-Dayton
# N-Newark
# 0-Philadelphia
# P-Birmingham
# Q-Pittsburgh
# R-Chicago-Rush
# S-Rutgers
# T-Columbia
# U-Los Angeles
# V-Miami
# WUOHHOOHOOOHOOHH HOHOWO
# All Clinics Combined
# 19
# IWAOHOOHOOHOH HOOHOOOOWO
# U ODONHOHHOHONHOHNHOHOMC
# Source: https://www.industrydocuments.ucsf.edu/docs/fgvh0227
#
# Questions:
# 1. What is the table number?
# 2. Which is clinical center A ?
# 3. What is the no.of UC participants lost to follow-up in New York?
# 4. What is the total number of participants lost to follow-up in Baltimore?
#
# Answers: ASSISTANT: 1. 516
# 2. A-Baltimore
# 3. 1
# 4. 19
#
# [Document: fgxh0227_5]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# Date :
# Re: ATTENDANCE REPORT FOR MONTH OF:
# (to be mailed on or before the last working day of month)
# Date of
# Hours
# Service
# Worked
# Purpose and or Place
# 11
# 1 1
# (signature of special consultant)
# Source: https://www.industrydocuments.ucsf.edu/docs/fgxh0227
#
# Questions:
# 1. What type of report is this?
# 2. Who should sign?
# 3. What is the heading of the first column?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# ...
#
# Document text:
# Office of Congressional and Intergovernmental Relations
# Water, Pesticides and Toxics Team
# Week of April 3, 2017
# HOT ISSUES:
# WIIN/WRDA (Matt)
# 1-4, dioxane in drinking water and under TSCA (Matt/Sven)
# .
# TSCA reform implementation (Sven)
# Lead in drinking water (Matt)
# WIFIA implementation (Matt)
# Waters of the U.S., Executive Order, litigation, & replacement rulemaking (Denis)
# Bristol Bay/Pebble Mine (Denis)
# National Estuary Program (Denis)
# Integrated planning (Kevin)
# MEETINGS/BRIEFINGS/ANNOUNCEMENTS:
# Mar 30 - Congressional Estuary Caucus staff briefing on estuary management and research w/OW,
# NOAA/OHC & OCM, and DOI/FWS (Denis)
# Mar 30 - Notification of chlorpyrifos petition denial w/OCSPP (Sven)
# Mar 30 - Notification of TSCA Reform mercury report w/OCSPP (Sven)
# Mar 31 - HEC TA request on asset management for drinking water systems w/OW, OECA (Kevin)
# Mar 30 - Sen. Collins (ME) and King (ME) staff briefing on ME Water Quality Standards ( Denis)
# Week of Apr 3 - Hill notifications on FY17 DWSRF American Iron & Steel memo w/OW (Matt)
# April 19 - Cong. Peters (CA) and Cong. Vargas (CA) invited to meeting in San Francisco Regional Office
# to Discuss Tijuana River and New River w/R9 (Kevin)
# TBD - House T&I bipartisan staff briefing on WIFIA implementation w/OW (Matt)
# TBD - House and Senate staff briefing on TSCA reform progress w/OCSPP (Sven)
# TBD - SEPW minority staff briefing on TSCA section 5 new chemicals program w/OCSPP, OGC (Sven)
# HEARINGS/MARKUPS:
# Topic:
# Legislative Hearing on: S. 518, a bill to amend the Federal Water Pollution Control Act to
# provide for technical assistance for small treatment works; S. 692, the "Water
# Infrastructure Flexibility Act of 2017;" and S. 675, the "Long Island Sound Restoration
# and Stewardship Act"
# Committee:
# Senate Committee Environment & Public Works
# Date:
# March 28, 2017
# Witness:
# No EPA Witness (Statement requested)
# Contacts:
# Kevin Kuhn, Denis Borum
# 115th CONGRESS LEGISLATION:
# HR 465 - Gibbs (OH), codifies integrated wastewater and stormwater planning (Kevin)
# HR 953 - Gibbs (OH), stops NPDES pesticide general permit, Passed House Ag Feb 16 (Kevin)
# HR 1029 - Davis (IL), reauthorizes pesticide registration fees, Passed the House March 20 (Sven)
# Source: https://www.industrydocuments.ucsf.edu/docs/fhcn025%_001225_00000014-00001
#
# Questions:
# 1. What is the date mentioned in the heading?
# 2. Are there any names mentioned in the Witness?
# 3. What is the first HOT ISSUE mentioned?
#
# Answers: ASSISTANT: 1. March 28, 2017
# 2. No EPA Witness (Statement requested)
# 3. WIIN/WRDA (Matt)
#
# [Document: fhjc0228_2]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# This form is provided to help you balance your bank statement
# IF YOUR ACCOUNT
# HAS AN AVERAGE
# YOUR SERVICE
# CHECKS OUTSTANDING-NOT
# BALANCE PER MONTH OF:
# CHARGE WILL BE:
# CHARGED TO ACCOUNT
# CHECK NUMBER
# AMOUNT
# MONTH
# Less than $100
# 64 for each check
# plus 754 base charge
# $100 to $200
# 64 for each check
# Bank balance shown on this statement
# plus 504 base charge
# $200 to $300
# 64 for each check
# plus 25d base charge
# ADD +
# Deposits not credited in this statement (if any) $
# $300 to $400
# 6+ for each check
# $400 to $500
# Five free checks, 64 for each
# additional check
# $500 to $600
# Ten free checks, 64 for each
# TOTAL
# $
# additional check
# Etc.
# Five additional free checks for each
# additional $100 average balance.
# SUBTRACT-
# Checks outstanding
# $
# If you do not write any checks there will be no charge.
# BALANCE
# $
# If total Service Charge amounts to less than 25q.
# the Service Charge will be 25c.
# TOTAL
# Should agree with your check book balance after deducting service charge (if any)
# The big difference in
# our auto loans . . .
# they're tailor-made.
# At First American you can get an individual-
# ized car loan. One just to suit your needs.
# With payments you can afford. And you can
# take 18 months, two years, three years to
# repay. That's the thing about First American.
# We'll work out the kind of loan you need.
# To fit your pattern. And at bank rates.
# FIRST AMERICAN
# NATIONAL BANK / 21 Convenient Locations
# MEMBER FEDERAL DEPOSIT INSURANCE CORPORATION
# Accounts insured to $15,000.00
# does/thic0228
#
# Questions:
# 1. What is the name of the bank advertised?
# 2. How many locations does the bank have?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# This form is provided to help you balance your bank statement
# IF YOUR ACCOUNT
# HAS AN AVERAGE
# YOUR SERVICE
# CHECKS OUTSTANDING-NOT
# BALANCE PER MONTH OF:
# CHARGE WILL BE:
# CHARGED TO ACCOUNT
# CHECK NUMBER
# AMOUNT
# MONTH
# Less than $100
# 64 for each check
# plus 754 base charge
# $100 to $200
# 64 for each check
# Bank balance shown on this statement
# plus 504 base charge
# $200 to $300
# 64 for each check
# plus 25d base charge
# ADD +
# Deposits not credited in this statement (if any) $
# $300 to $400
# 6+ for each check
# $400 to $500
# Five free checks, 64 for each
# additional check
# $500 to $600
# Ten free checks, 64 for each
# TOTAL
# $
# additional check
# Etc.
# Five additional free checks for each
# additional $100 average balance.
# SUBTRACT-
# Checks outstanding
# $
# If you do not write any checks there will be no charge.
# BALANCE
# $
# If total Service Charge amounts to less than 25q.
# the Service Charge will be 25c.
# TOTAL
# Should agree with your check book balance after deducting service charge (if any)
# The big difference in
# our auto loans . . .
# they're tailor-made.
# At First American you can get an individual-
# ized car loan. One just to suit your needs.
# With payments you can afford. And you can
# take 18 months, two years, three years to
# repay. That's the thing about First American.
# We'll work out the kind of loan you need.
# To fit your pattern. And at bank rates.
# FIRST AMERICAN
# NATIONAL BANK / 21 Convenient Locations
# MEMBER FEDERAL DEPOSIT INSURANCE CORPORATION
# Accounts insured to $15,000.00
# does/thic0228
#
# Questions:
# 1. What is the name of the bank advertised?
# 2. How many locations does the bank have?
#
# Answers: ASSISTANT: 1. First American National Bank
# 2. 21
#
# [Document: fhng0227_16]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# WOHL CLINIC
# DR. R. SHANK
# 4950 AUDUBON
# OTIS ELEVATOR CO.
# ATTN: MR. BRINKMAN
# 2301 LOCUST ST.
# ORDER NO. 49372
# CITY
# PA73WBC43
# Req. 4 - 00581
# 6-12-61
# INSTALL HOOKS & REMOVABLE PADDING IN ONE ELEVATOR
# AT THE WOHL CLINIC BLDG.
# 90 . 00
# Sent copies to hill & Miss Kaiser
# 8/2/61
# Source: https://www.industrydocuments.ucsf.edu/docs/fhng0227
#
# Questions:
# 1. What is the order number?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# WOHL CLINIC
# DR. R. SHANK
# 4950 AUDUBON
# OTIS ELEVATOR CO.
# ATTN: MR. BRINKMAN
# 2301 LOCUST ST.
# ORDER NO. 49372
# CITY
# PA73WBC43
# Req. 4 - 00581
# 6-12-61
# INSTALL HOOKS & REMOVABLE PADDING IN ONE ELEVATOR
# AT THE WOHL CLINIC BLDG.
# 90 . 00
# Sent copies to hill & Miss Kaiser
# 8/2/61
# Source: https://www.industrydocuments.ucsf.edu/docs/fhng0227
#
# Questions:
# 1. What is the order number?
#
# Answers: ASSISTANT: 49372
#
# [Document: fhnw0228_1]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# SOUTHWARK STREET, LONDON, S.E.I
# RARE BOOKS .
# AUTOGRAPHS . MANUSCRIPTS .
# OLD
# MAPS
# TELEGRAMS & CABLES
# BIBLIOLITE . LONDON.W.I
# MAGGS BROS. LTD
# TELEPHONES
# 50, Berkeley Square, London, WIX 6EL 01-499 2007 & 01-499 205/
# PAYMENTS RECEIVED
# DR.W.J. DARBY,
# SINCE THIS DATE
# DEPT. OF BIOCHEMISTRY,
# NOT INCLUDED.
# SCHOOL OF MEDICINE.
# GEORGE ANSON & COMPANY LIMITED.
# VANDERBILT UNIVERSITY
# STATION 17
# NASHVILLE , TENN. 37203.
# 3 0 NOV 1969
# STATEMENT
# 19
# US.A.
# DATE
# REF
# DETAILS
# DEBIT
# CREDIT
# BALANCE
# Sept Der. 18 BfFuel.
# E
# 4 8
# 13 /7
# TO REPEAT PLEASE QUOTE FORM No. A$2/19825(8/68)
#
# Questions:
# 1. What is the name of the company?
# 2. Who is the client?
# 3. What type of maps do they specialize in?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# SOUTHWARK STREET, LONDON, S.E.I
# RARE BOOKS .
# AUTOGRAPHS . MANUSCRIPTS .
# OLD
# MAPS
# TELEGRAMS & CABLES
# BIBLIOLITE . LONDON.W.I
# MAGGS BROS. LTD
# TELEPHONES
# 50, Berkeley Square, London, WIX 6EL 01-499 2007 & 01-499 205/
# PAYMENTS RECEIVED
# DR.W.J. DARBY,
# SINCE THIS DATE
# DEPT. OF BIOCHEMISTRY,
# NOT INCLUDED.
# SCHOOL OF MEDICINE.
# GEORGE ANSON & COMPANY LIMITED.
# VANDERBILT UNIVERSITY
# STATION 17
# NASHVILLE , TENN. 37203.
# 3 0 NOV 1969
# STATEMENT
# 19
# US.A.
# DATE
# REF
# DETAILS
# DEBIT
# CREDIT
# BALANCE
# Sept Der. 18 BfFuel.
# E
# 4 8
# 13 /7
# TO REPEAT PLEASE QUOTE FORM No. A$2/19825(8/68)
#
# Questions:
# 1. What is the name of the company?
# 2. Who is the client?
# 3. What type of maps do they specialize in?
#
# Answers: ASSISTANT: 1. Maggs Bros. Ltd.
# 2. Dr. W.J. Darby
# 3. Old maps
#
# [Document: fhwc0228_12]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# Source: 1967/68 Menu Census
# TABLE 2
# FREQUENCY DISTRIBUTION OF SHEETNER USAGE
# - Among Dieters and Weight Watchers
# Times Used:
# Persons Using
# -- --Percent Total Uses---.
# No.
# %
# Liquid
# Granule
# Tablet
# All Other
# Total
# 1 - 5 times
# 382
# 42.9%
# 48.9%
# 10.4%
# 26.9%
# 13.8%
# 100.0:
# 6 - 10 times
# 128
# 14. 4
# 52.2
# 8.5
# 29.5
# 9 .8
# 100.0%
# 11 - 20 times
# 225
# 25.2
# 46.7
# 7.3
# 38.1
# 7.9
# 100. C.
# 21 - 30 times
# 97
# 10.9
# 40.1
# 13.3
# 39.9
# 6.7
# 100. CT.
# 31 or more times
# 59
# 6.6
# 39.9
# 7.8
# 45.7
# 6.6
# 100.03
# 89 1
# 100 . 0%
# - Among Non - Dieters -
# Times Used:
# Persons Using
# - -Percent Total Uses---
# No.
# %%
# Liquid
# Granule
# Tablet
# All Other
# Total
# 1 - 5 times
# 273
# 56.9%
# 43.8%
# 9.7%
# 34. 1%
# 12.4
# 100. C
# 6 - 10 times
# 78
# 16.3
# 50.5
# 9 . 7
# 31.6
# 8. 2
# 100 . 07:
# 11 - 20 times
# 86
# 17.9
# 23.2
# 13.4
# 55.0
# 8. 4
# 100.0:
# 21 - 30 times
# 30
# 6.3
# 28.8
# 3.3
# 50.6
# 17.3
# 100 . 0::
# 31 or more times
# 13
# 2.7
# 2.2
# 7.0
# 75.0
# 15.8
# 100.G.
# 480
# 100.0%
# du/doc
#
# Questions:
# 1. What is ‘table 2’ ?
# 2. Among dieters and weight watchers, how many persons used sweetner ‘1-5 times’ ?
# 3. Among dieters and weight watchers, how many persons used ‘31 or more times’ ?
# 4. Among dieters and weight watchers, how many  persons used ‘21-30 times’ ?
# 5. Among dieters and weight watchers, how many  persons used ‘11-20 times’ ?
# 6. Among dieters and weight watchers, how many persons used ‘6-10 times’ ?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# Source: 1967/68 Menu Census
# TABLE 2
# FREQUENCY DISTRIBUTION OF SHEETNER USAGE
# - Among Dieters and Weight Watchers
# Times Used:
# Persons Using
# -- --Percent Total Uses---.
# No.
# %
# Liquid
# Granule
# Tablet
# All Other
# Total
# 1 - 5 times
# 382
# 42.9%
# 48.9%
# 10.4%
# 26.9%
# 13.8%
# 100.0:
# 6 - 10 times
# 128
# 14. 4
# 52.2
# 8.5
# 29.5
# 9 .8
# 100.0%
# 11 - 20 times
# 225
# 25.2
# 46.7
# 7.3
# 38.1
# 7.9
# 100. C.
# 21 - 30 times
# 97
# 10.9
# 40.1
# 13.3
# 39.9
# 6.7
# 100. CT.
# 31 or more times
# 59
# 6.6
# 39.9
# 7.8
# 45.7
# 6.6
# 100.03
# 89 1
# 100 . 0%
# - Among Non - Dieters -
# Times Used:
# Persons Using
# - -Percent Total Uses---
# No.
# %%
# Liquid
# Granule
# Tablet
# All Other
# Total
# 1 - 5 times
# 273
# 56.9%
# 43.8%
# 9.7%
# 34. 1%
# 12.4
# 100. C
# 6 - 10 times
# 78
# 16.3
# 50.5
# 9 . 7
# 31.6
# 8. 2
# 100 . 07:
# 11 - 20 times
# 86
# 17.9
# 23.2
# 13.4
# 55.0
# 8. 4
# 100.0:
# 21 - 30 times
# 30
# 6.3
# 28.8
# 3.3
# 50.6
# 17.3
# 100 . 0::
# 31 or more times
# 13
# 2.7
# 2.2
# 7.0
# 75.0
# 15.8
# 100.G.
# 480
# 100.0%
# du/doc
#
# Questions:
# 1. What is ‘table 2’ ?
# 2. Among dieters and weight watchers, how many persons used sweetner ‘1-5 times’ ?
# 3. Among dieters and weight watchers, how many persons used ‘31 or more times’ ?
# 4. Among dieters and weight watchers, how many  persons used ‘21-30 times’ ?
# 5. Among dieters and weight watchers, how many  persons used ‘11-20 times’ ?
# 6. Among dieters and weight watchers, how many persons used ‘6-10 times’ ?
#
# Answers: ASSISTANT: 1. Table 2 is a table in a document that shows the frequency distribution of sweetner usage among dieters and weight watchers.
# 2. Among dieters and weight watchers, 382 persons used sweetner "1-5 times".
# 3. Among dieters and weight watchers, 59 persons used sweetner "31 or more times".
# 4. Among dieters and weight watchers, 225 persons used sweetner "21-30 times".
# 5. Among dieters and weight watchers, 128 persons used sweetner "11-20 times".
# 6. Among dieters and weight watchers, 78 persons used sweetner "6-10 times".
#
# [Document: fhxn0226_2]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# 2011 Review of Pinnacle Ultamet Experience for
# Drs. Griffin and Mason
# Dates
# Total
# No Reported
# No Reported
# Implanted
# Implanted
# Revisions
# Metal Reaction
# Revisions
# 2001-2008
# 1 100
# 1087
# 1094
# (98.8%)
# (99.5%)
# P-00594-00002
# Source: https://www.industrydocuments.ucsf.edu/docs/fhxn0226
#
# Questions:
# 1. What is the year of review of pinnacle ultamet experience?
# 2. What are the ‘dates implanted’?
# 3. How many ‘total implanted’?
# 4. How many’ no reported revisions’?
# 5. How many ‘ no reported metal reaction revisions’?
# 6. What is the percentage shown under ‘no reported revisions’?
# 7. What is the percentage shown under ‘no reported metal reaction revisions’?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# 2011 Review of Pinnacle Ultamet Experience for
# Drs. Griffin and Mason
# Dates
# Total
# No Reported
# No Reported
# Implanted
# Implanted
# Revisions
# Metal Reaction
# Revisions
# 2001-2008
# 1 100
# 1087
# 1094
# (98.8%)
# (99.5%)
# P-00594-00002
# Source: https://www.industrydocuments.ucsf.edu/docs/fhxn0226
#
# Questions:
# 1. What is the year of review of pinnacle ultamet experience?
# 2. What are the ‘dates implanted’?
# 3. How many ‘total implanted’?
# 4. How many’ no reported revisions’?
# 5. How many ‘ no reported metal reaction revisions’?
# 6. What is the percentage shown under ‘no reported revisions’?
# 7. What is the percentage shown under ‘no reported metal reaction revisions’?
#
# Answers: ASSISTANT: 1. 2001-2008
# 2. 2001-2008
# 3. 1087
# 4. 0
# 5. 0
# 6. (98.8%)
# 7. (99.5%)
#
# [Document: fjyn0081_24]
# --- Combined Prompt Sent ---
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# 51337 9206
# Select Share Of Market
# - High Mkt
# -O- Weak Mikt
# 3.5
# 3
# 2.5
# 2
# 1.5
# 0.5
# O
# Oct
# Nov
# Dec
# Jan
# Feb
# Mar
#
# Questions:
# 1. What is the first month plotted along the x axis?
# 2. What is the last month plotted along the x axis?
# 3. What is the share of high market in dec?
#
# Answers:
#
# --- Combined Output Received ---
# USER:
# Based on the document image and text, answer each of the following questions. Provide each answer on a new line, prefixed with the question number (e.g., "1. [answer]").
#
# Document text:
# 51337 9206
# Select Share Of Market
# - High Mkt
# -O- Weak Mikt
# 3.5
# 3
# 2.5
# 2
# 1.5
# 0.5
# O
# Oct
# Nov
# Dec
# Jan
# Feb
# Mar
#
# Questions:
# 1. What is the first month plotted along the x axis?
# 2. What is the last month plotted along the x axis?
# 3. What is the share of high market in dec?
#
# Answers: ASSISTANT: 1. 0.5
# 2. 1.5
# 3. 3.5
#
# Processing complete. All results saved to /content/prompt_outputs_multimodal_val.json

# %%
if all_data:
    # Calculate average ANLS
    average_anls = np.mean([item['anls_score'] for item in all_data])

    # Calculate average Extractive Match
    average_extractive_match = np.mean([item['extractive_match'] for item in all_data])

    # Calculate Possible and Actual from strict match counts
    possible_count = strict_match_counts["Correct"] + strict_match_counts["Incorrect"] + strict_match_counts["Missing"]
    actual_count = strict_match_counts["Correct"] + strict_match_counts["Incorrect"] + strict_match_counts["Spurious"]

    print(f"\n--- Overall Metrics ---")
    print(f"Total Questions Processed: {len(all_data)}")
    print(f"Average ANLS: {average_anls:.4f}")
    print(f"Average Extractive Match: {average_extractive_match:.4f}")

    print("\n--- Strict Match Breakdown ---")
    for category, count in strict_match_counts.items():
        print(f"{category}: {count}")
    print(f"\nPossible: {possible_count}")
    print(f"Actual: {actual_count}")

    print("\n--- Confusion Matrix (Extractive) ---")
    print(f"True Positives (TP):  {confusion_matrix_counts['tp']}")
    print(f"False Positives (FP): {confusion_matrix_counts['fp']}")
    print(f"True Negatives (TN):  {confusion_matrix_counts['tn']}")
    print(f"False Negatives (FN): {confusion_matrix_counts['fn']}")

else:
    print("\nNo data was processed to calculate average scores.")
# Out:
# --- Overall Metrics ---
# Total Questions Processed: 86
# Average ANLS: 0.4481
# Average Extractive Match: 0.4651
#
# --- Strict Match Breakdown ---
# Correct: 23
# Incorrect: 63
# Missing: 0
# Spurious: 0
#
# Possible: 86
# Actual: 86
#
# --- Confusion Matrix (Extractive) ---
# True Positives (TP):  40
# False Positives (FP): 0
# True Negatives (TN):  0
# False Negatives (FN): 46

# %%
# Out:
# G W Sugar refers to Great Western Sugar Company, which was a sugar company based in Denver, Colorado. The company was known for producing sugar and other related products. The image shows a receipt from the Great Western Sugar Company, which indicates that the company was involved in the sugar trade and distribution.</s>

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!
#
# We use our new `UnslothVisionDataCollator` which will help in our vision finetuning setup.

# %%
from unsloth.trainer import UnslothVisionDataCollator
from trl import SFTTrainer, SFTConfig

FastVisionModel.for_training(model) # Enable for training!

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    data_collator = UnslothVisionDataCollator(model, tokenizer), # Must use!
    train_dataset = converted_dataset,
    args = SFTConfig(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = 30,
        # num_train_epochs = 1, # Set this instead of max_steps for full training runs
        learning_rate = 2e-4,
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none",     # For Weights and Biases

        # You MUST put the below items for vision finetuning:
        remove_unused_columns = False,
        dataset_text_field = "",
        dataset_kwargs = {"skip_prepare_dataset": True},
        max_seq_length = 2048,
    ),
)
# Out:
# Unsloth: Model does not have a default image size - using 512

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.741 GB.
# 6.068 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 68,686 | Num Epochs = 1 | Total steps = 30
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 51,521,536/7,000,000,000 (0.74% trained)
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 02:59, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.787200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.326000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.431700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.313500</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.053400</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.038500</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.522700</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.004700</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.716800</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.744900</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.611900</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.499200</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.369000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.361600</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.353800</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.252400</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.183800</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.196700</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.126000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.190200</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.183100</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.164300</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.130300</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.098900</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.195100</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.140000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.081400</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.235800</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.085400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.131800</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 219.9988 seconds used for training.
# 3.67 minutes used for training.
# Peak reserved memory = 6.484 GB.
# Peak reserved memory for training = 0.416 GB.
# Peak reserved memory % of max memory = 43.986 %.
# Peak reserved memory for training % of max memory = 2.822 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!
#
# We use `min_p = 0.1` and `temperature = 1.5`. Read this [Tweet](https://x.com/menhguin/status/1826132708508213629) for more information on why.

# %%
FastVisionModel.for_inference(model) # Enable for inference!

image = dataset[2]["image"]
instruction = "Write the LaTeX representation for this image."

messages = [
    {"role": "user", "content": [
        {"type": "image"},
        {"type": "text", "text": instruction}
    ]}
]
input_text = tokenizer.apply_chat_template(messages, add_generation_prompt = True)
inputs = tokenizer(
    image,
    input_text,
    add_special_tokens = False,
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128,
                   use_cache = True, temperature = 1.5, min_p = 0.1)
# Out:
# H ^ { \prime } = \beta N \int d \lambda \left\{ \frac { 1 } { 2 \beta ^ { 2 } \bar { N } ^ { 2 } } \partial _ { \lambda } \zeta ^ { \dagger } \partial _ { \lambda } \zeta + V ( \lambda ) \zeta ^ { \dagger } \zeta \right\} .<|im_end|>

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model")  # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# []

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastVisionModel
    model, tokenizer = FastVisionModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit = True, # Set to False for 16bit LoRA
    )
    FastVisionModel.for_inference(model) # Enable for inference!

image = dataset[0]["image"]
instruction = "Write the LaTeX representation for this image."

messages = [
    {"role": "user", "content": [
        {"type": "image"},
        {"type": "text", "text": instruction}
    ]}
]
input_text = tokenizer.apply_chat_template(messages, add_generation_prompt = True)
inputs = tokenizer(
    image,
    input_text,
    add_special_tokens = False,
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128,
                   use_cache = True, temperature = 1.5, min_p = 0.1)
# Out:
# \frac { N } { M } \in \mathbf { Z } , \frac { P } { Q } \in \mathbf { Z } , P \in \mathbf { Z }<|im_end|>

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Select ONLY 1 to save! (Both not needed!)

# Save locally to 16bit
if False: model.save_pretrained_merged("unsloth_finetune", tokenizer,)

# To export and save to your Hugging Face account
if False: model.push_to_hub_merged("YOUR_USERNAME/unsloth_finetune", tokenizer, token = "PUT_HERE")

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/u54VK8m8tk) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
